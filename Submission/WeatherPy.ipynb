# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Requests
import requests
import json
import time
from pprint import pprint

# Data Science
import pandas as pd
import numpy as np
import scipy.stats as sc

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        if (response.status_code == 200):
            # Extract data
            city_weather = response.json()

            # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
            city_name = city_weather.get("name")
            city_country = city_weather.get("sys", {}).get("country")
            city_date = city_weather.get("dt")
            city_humidity = city_weather.get("main", {}).get("humidity")
            city_max_temp = city_weather.get("main", {}).get("temp_max")
            city_pressure = city_weather.get("main", {}).get("pressure")
            city_clouds = city_weather.get("clouds", {}).get("all")
            city_wind = city_weather.get("wind", {}).get("speed")
    
            city_lat = city_weather.get("coord", {}).get("lat")
            city_lng = city_weather.get("coord", {}).get("lon")

            # Append the City information into city_data list
            city_data.append({"City": city_name,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Pressure": city_pressure,
                              "Country": city_country,
                              "Date": city_date})
        else:
            print(f"YO! The API threw a non-200 status code: {response['status_code']} for city {city}") # error log
            print()
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | weno
# Processing Record 2 of Set 1 | kil'mez'
# City not found. Skipping...
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | brisas de zicatela
# Processing Record 5 of Set 1 | klyuchi
# Processing Record 6 of Set 1 | pugachev
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | invercargill
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | vorgashor
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 | adamstown
# Processing Record 14 of Set 1 | namibe
# Processing Record 15 of Set 1 | west island
# Processing Record 16 of Set 1 | iwanai
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | wad az zaki
# Processing Record 19 of Set 1 | oranjemund
# Processing Record 20 of Set 1 | chonchi
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | olonkinbyen
# Processing Record 23 of Set 1 | yinchuan
# Processing Record 24 of Set 1 | san antonio de pale
# Processing Record 25 of Set 1 | broken hill
# Processing Record 26 of Set 1 | mountain home
# Processing Record 27 of Set 1 | mandalgovi
# Processing Record 28 of Set 1 | aasiaat
# Processing Record 29 of Set 1 | kone
# Processing Record 30 of Set 1 | rio grande
# Processing Record 31 of Set 1 | kidal
# Processing Record 32 of Set 1 | ust-nera
# Processing Record 33 of Set 1 | qaqortoq
# Processing Record 34 of Set 1 | praia da vitoria
# Processing Record 35 of Set 1 | lorengau
# Processing Record 36 of Set 1 | mil'kovo
# Processing Record 37 of Set 1 | kyzyl-mazhalyk
# Processing Record 38 of Set 1 | puerto natales
# Processing Record 39 of Set 1 | bilibino
# Processing Record 40 of Set 1 | constantia
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | casper
# Processing Record 43 of Set 1 | fortuna
# Processing Record 44 of Set 1 | portland
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | port-aux-francais
# Processing Record 47 of Set 1 | nyakahanga
# Processing Record 48 of Set 1 | kununurra
# Processing Record 49 of Set 1 | muisne
# Processing Record 50 of Set 1 | badr hunayn
# Processing Record 0 of Set 2 | zhezqazghan
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | port mathurin
# Processing Record 3 of Set 2 | namtsy
# Processing Record 4 of Set 2 | severobaykal'sk
# Processing Record 5 of Set 2 | lianzhou
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | hawaiian paradise park
# Processing Record 8 of Set 2 | uliastay
# Processing Record 9 of Set 2 | dunedin
# Processing Record 10 of Set 2 | whangarei
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | kuanda
# Processing Record 14 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 2 | nurabad
# Processing Record 16 of Set 2 | valle nacional
# Processing Record 17 of Set 2 | skurup
# Processing Record 18 of Set 2 | margaret river
# Processing Record 19 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | cidreira
# Processing Record 22 of Set 2 | riverton
# Processing Record 23 of Set 2 | pantai remis
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | anqiu
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | talnakh
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | badger
# Processing Record 30 of Set 2 | sapucaia
# Processing Record 31 of Set 2 | kalamata
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | igatpuri
# Processing Record 34 of Set 2 | saguenay
# Processing Record 35 of Set 2 | alotau
# Processing Record 36 of Set 2 | antsiranana
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | kuala lumpur
# Processing Record 39 of Set 2 | ta`u
# Processing Record 40 of Set 2 | narasannapeta
# Processing Record 41 of Set 2 | bunia
# Processing Record 42 of Set 2 | santa marta
# Processing Record 43 of Set 2 | alice springs
# Processing Record 44 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 45 of Set 2 | buzovna
# Processing Record 46 of Set 2 | ushuaia
# Processing Record 47 of Set 2 | la passe
# Processing Record 48 of Set 2 | hasaki
# Processing Record 49 of Set 2 | fort st. john
# Processing Record 0 of Set 3 | vadso
# Processing Record 1 of Set 3 | kataragama
# City not found. Skipping...
# Processing Record 2 of Set 3 | kayyerkan
# Processing Record 3 of Set 3 | shalqar
# Processing Record 4 of Set 3 | argo
# Processing Record 5 of Set 3 | pericos
# Processing Record 6 of Set 3 | qamdo
# Processing Record 7 of Set 3 | nadym
# Processing Record 8 of Set 3 | albany
# Processing Record 9 of Set 3 | papatowai
# Processing Record 10 of Set 3 | frontera
# Processing Record 11 of Set 3 | susuman
# Processing Record 12 of Set 3 | rosso
# Processing Record 13 of Set 3 | kapa'a
# Processing Record 14 of Set 3 | polyarnyy
# Processing Record 15 of Set 3 | mirpur sakro
# Processing Record 16 of Set 3 | watsa
# Processing Record 17 of Set 3 | salmon arm
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | eyl
# Processing Record 20 of Set 3 | hwange
# Processing Record 21 of Set 3 | rudsar
# Processing Record 22 of Set 3 | wailua homesteads
# Processing Record 23 of Set 3 | chul'man
# Processing Record 24 of Set 3 | bridgewater
# Processing Record 25 of Set 3 | xining
# Processing Record 26 of Set 3 | banda aceh
# Processing Record 27 of Set 3 | afaahiti
# Processing Record 28 of Set 3 | st. john's
# Processing Record 29 of Set 3 | kargasok
# Processing Record 30 of Set 3 | keflavik
# Processing Record 31 of Set 3 | dursunbey
# Processing Record 32 of Set 3 | kilindoni
# Processing Record 33 of Set 3 | whitehorse
# Processing Record 34 of Set 3 | udachny
# Processing Record 35 of Set 3 | colares
# Processing Record 36 of Set 3 | kerikeri
# Processing Record 37 of Set 3 | ulety
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | nemuro
# Processing Record 40 of Set 3 | kasongo-lunda
# Processing Record 41 of Set 3 | blackmans bay
# Processing Record 42 of Set 3 | cadale
# Processing Record 43 of Set 3 | lucea
# Processing Record 44 of Set 3 | road town
# Processing Record 45 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 46 of Set 3 | yanam
# Processing Record 47 of Set 3 | tazacorte
# Processing Record 48 of Set 3 | hadibu
# Processing Record 49 of Set 3 | dilling
# Processing Record 0 of Set 4 | taltal
# Processing Record 1 of Set 4 | college
# Processing Record 2 of Set 4 | kattivakkam
# Processing Record 3 of Set 4 | mount isa
# Processing Record 4 of Set 4 | thanesar
# Processing Record 5 of Set 4 | yeniseysk
# Processing Record 6 of Set 4 | atafu village
# Processing Record 7 of Set 4 | nyurba
# Processing Record 8 of Set 4 | nguigmi
# Processing Record 9 of Set 4 | aripuana
# Processing Record 10 of Set 4 | duki
# Processing Record 11 of Set 4 | ola
# Processing Record 12 of Set 4 | lihue
# Processing Record 13 of Set 4 | taveta
# Processing Record 14 of Set 4 | uturoa
# Processing Record 15 of Set 4 | darwin
# Processing Record 16 of Set 4 | howrah
# Processing Record 17 of Set 4 | edinburgh of the seven seas
# Processing Record 18 of Set 4 | saint-francois
# Processing Record 19 of Set 4 | westport
# Processing Record 20 of Set 4 | almenara
# Processing Record 21 of Set 4 | cockburn town
# Processing Record 22 of Set 4 | yanchep
# Processing Record 23 of Set 4 | saipan
# Processing Record 24 of Set 4 | fisterra
# Processing Record 25 of Set 4 | los llanos de aridane
# Processing Record 26 of Set 4 | pangai
# Processing Record 27 of Set 4 | trondheim
# Processing Record 28 of Set 4 | talara
# Processing Record 29 of Set 4 | pangoa
# Processing Record 30 of Set 4 | puerto lempira
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | leava
# Processing Record 33 of Set 4 | ceeldheer
# Processing Record 34 of Set 4 | dzhalagash
# Processing Record 35 of Set 4 | parauapebas
# Processing Record 36 of Set 4 | anabar
# City not found. Skipping...
# Processing Record 37 of Set 4 | austin
# Processing Record 38 of Set 4 | gaoping
# Processing Record 39 of Set 4 | thunder bay
# Processing Record 40 of Set 4 | port elizabeth
# Processing Record 41 of Set 4 | tolanaro
# Processing Record 42 of Set 4 | biltine
# Processing Record 43 of Set 4 | ust-tsilma
# Processing Record 44 of Set 4 | solnechnyy
# Processing Record 45 of Set 4 | al abyar
# Processing Record 46 of Set 4 | fort bragg
# Processing Record 47 of Set 4 | vila franca do campo
# Processing Record 48 of Set 4 | ilulissat
# Processing Record 49 of Set 4 | byron bay
# Processing Record 0 of Set 5 | tazovsky
# Processing Record 1 of Set 5 | okhotsk
# Processing Record 2 of Set 5 | las khorey
# Processing Record 3 of Set 5 | gereida
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | stanley
# Processing Record 6 of Set 5 | murud
# Processing Record 7 of Set 5 | caleta de carquin
# Processing Record 8 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 9 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 10 of Set 5 | smirnykh
# Processing Record 11 of Set 5 | gao
# Processing Record 12 of Set 5 | port lincoln
# Processing Record 13 of Set 5 | haiku-pauwela
# Processing Record 14 of Set 5 | palanga
# Processing Record 15 of Set 5 | east london
# Processing Record 16 of Set 5 | borodino
# Processing Record 17 of Set 5 | bikenibeu village
# Processing Record 18 of Set 5 | dundee
# Processing Record 19 of Set 5 | hualien city
# Processing Record 20 of Set 5 | meiganga
# Processing Record 21 of Set 5 | selfoss
# Processing Record 22 of Set 5 | mora
# Processing Record 23 of Set 5 | wenling
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | lalpur
# Processing Record 26 of Set 5 | crane
# Processing Record 27 of Set 5 | koshki
# Processing Record 28 of Set 5 | dudinka
# Processing Record 29 of Set 5 | joshimath
# Processing Record 30 of Set 5 | gizo
# Processing Record 31 of Set 5 | yelizovo
# Processing Record 32 of Set 5 | yemva
# Processing Record 33 of Set 5 | gharghoda
# Processing Record 34 of Set 5 | logan square
# City not found. Skipping...
# Processing Record 35 of Set 5 | danjiangkou
# Processing Record 36 of Set 5 | galesong
# Processing Record 37 of Set 5 | scarborough
# Processing Record 38 of Set 5 | sicuani
# Processing Record 39 of Set 5 | midvagur
# Processing Record 40 of Set 5 | kangding
# Processing Record 41 of Set 5 | angermunde
# Processing Record 42 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 43 of Set 5 | saint-philippe
# Processing Record 44 of Set 5 | glace bay
# Processing Record 45 of Set 5 | bouznika
# Processing Record 46 of Set 5 | port augusta
# Processing Record 47 of Set 5 | cedar falls
# Processing Record 48 of Set 5 | figeac
# Processing Record 49 of Set 5 | oriental
# Processing Record 0 of Set 6 | itamaraca
# Processing Record 1 of Set 6 | mejit
# Processing Record 2 of Set 6 | lincoln
# Processing Record 3 of Set 6 | freeport
# Processing Record 4 of Set 6 | kiffa
# Processing Record 5 of Set 6 | pervomayskoye
# Processing Record 6 of Set 6 | bubaque
# Processing Record 7 of Set 6 | piensk
# Processing Record 8 of Set 6 | timimoun
# Processing Record 9 of Set 6 | kavaratti
# Processing Record 10 of Set 6 | farsan
# Processing Record 11 of Set 6 | guanica
# Processing Record 12 of Set 6 | utrik
# Processing Record 13 of Set 6 | tsiombe
# Processing Record 14 of Set 6 | la paz
# Processing Record 15 of Set 6 | malmberget
# Processing Record 16 of Set 6 | isangel
# Processing Record 17 of Set 6 | cabezon de la sal
# Processing Record 18 of Set 6 | zaozersk
# Processing Record 19 of Set 6 | colonia
# Processing Record 20 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 21 of Set 6 | happy valley-goose bay
# Processing Record 22 of Set 6 | tromso
# Processing Record 23 of Set 6 | nuku'alofa
# Processing Record 24 of Set 6 | champerico
# Processing Record 25 of Set 6 | kudahuvadhoo
# Processing Record 26 of Set 6 | jamestown
# Processing Record 27 of Set 6 | nagqu
# Processing Record 28 of Set 6 | hotan
# Processing Record 29 of Set 6 | puttalam
# Processing Record 30 of Set 6 | khanpur mahar
# Processing Record 31 of Set 6 | panaba
# Processing Record 32 of Set 6 | praia
# Processing Record 33 of Set 6 | kibaya
# Processing Record 34 of Set 6 | igarka
# Processing Record 35 of Set 6 | morant bay
# Processing Record 36 of Set 6 | nova sintra
# Processing Record 37 of Set 6 | mitu
# Processing Record 38 of Set 6 | chongwe
# Processing Record 39 of Set 6 | pierre
# Processing Record 40 of Set 6 | vila velha
# Processing Record 41 of Set 6 | rawlins
# Processing Record 42 of Set 6 | puerto baquerizo moreno
# Processing Record 43 of Set 6 | at taj
# Processing Record 44 of Set 6 | palmas
# Processing Record 45 of Set 6 | klaksvik
# Processing Record 46 of Set 6 | enewetak
# Processing Record 47 of Set 6 | kolonia town
# Processing Record 48 of Set 6 | shipston on stour
# Processing Record 49 of Set 6 | chiredzi
# Processing Record 0 of Set 7 | pobugskoye
# Processing Record 1 of Set 7 | kindu
# Processing Record 2 of Set 7 | sovetskaya gavan'
# Processing Record 3 of Set 7 | longyearbyen
# Processing Record 4 of Set 7 | myeik
# Processing Record 5 of Set 7 | palembang
# Processing Record 6 of Set 7 | ancud
# Processing Record 7 of Set 7 | gaigeturi
# Processing Record 8 of Set 7 | kingston
# Processing Record 9 of Set 7 | oualidia
# City not found. Skipping...
# Processing Record 10 of Set 7 | sokoni
# Processing Record 11 of Set 7 | prado
# Processing Record 12 of Set 7 | gulf breeze
# Processing Record 13 of Set 7 | santiago de cao
# Processing Record 14 of Set 7 | ulladulla
# Processing Record 15 of Set 7 | pakxan
# Processing Record 16 of Set 7 | reyes
# Processing Record 17 of Set 7 | taulaga
# Processing Record 18 of Set 7 | iskateley
# Processing Record 19 of Set 7 | mount gambier
# Processing Record 20 of Set 7 | grand-bassam
# Processing Record 21 of Set 7 | manicore
# Processing Record 22 of Set 7 | lompoc
# Processing Record 23 of Set 7 | bonthe
# Processing Record 24 of Set 7 | kalmunai
# Processing Record 25 of Set 7 | ambatolampy
# Processing Record 26 of Set 7 | saint-jean-de-monts
# Processing Record 27 of Set 7 | guerrero negro
# Processing Record 28 of Set 7 | carmi
# Processing Record 29 of Set 7 | vrangel'
# Processing Record 30 of Set 7 | olinda
# Processing Record 31 of Set 7 | pont-l'abbe
# City not found. Skipping...
# Processing Record 32 of Set 7 | minas de marcona
# Processing Record 33 of Set 7 | an muileann gcearr
# Processing Record 34 of Set 7 | labrador city
# Processing Record 35 of Set 7 | horodyshche
# Processing Record 36 of Set 7 | ghat
# Processing Record 37 of Set 7 | cheboksary
# Processing Record 38 of Set 7 | nykobing falster
# Processing Record 39 of Set 7 | zhangatas
# Processing Record 40 of Set 7 | mokrous
# Processing Record 41 of Set 7 | auki
# Processing Record 42 of Set 7 | nadi
# Processing Record 43 of Set 7 | san jose
# Processing Record 44 of Set 7 | kapuskasing
# Processing Record 45 of Set 7 | anadyr
# Processing Record 46 of Set 7 | fort-shevchenko
# Processing Record 47 of Set 7 | hohhot
# Processing Record 48 of Set 7 | almodovar del campo
# Processing Record 49 of Set 7 | labuan
# Processing Record 0 of Set 8 | mufumbwe
# Processing Record 1 of Set 8 | nuuk
# Processing Record 2 of Set 8 | celestun
# Processing Record 3 of Set 8 | santa maria
# Processing Record 4 of Set 8 | mata-utu
# Processing Record 5 of Set 8 | nizhniy kuranakh
# Processing Record 6 of Set 8 | patterson
# Processing Record 7 of Set 8 | komusan il-tong
# Processing Record 8 of Set 8 | lang son
# Processing Record 9 of Set 8 | kirensk
# Processing Record 10 of Set 8 | cold lake
# Processing Record 11 of Set 8 | port maria
# Processing Record 12 of Set 8 | bardai
# Processing Record 13 of Set 8 | gebeit
# Processing Record 14 of Set 8 | el matama
# Processing Record 15 of Set 8 | chernyshevsk
# Processing Record 16 of Set 8 | buta
# Processing Record 17 of Set 8 | karratha
# Processing Record 18 of Set 8 | callaway
# Processing Record 19 of Set 8 | barcelos
# Processing Record 20 of Set 8 | kudymkar
# Processing Record 21 of Set 8 | general conesa
# Processing Record 22 of Set 8 | balad
# Processing Record 23 of Set 8 | loralai
# Processing Record 24 of Set 8 | saint-pierre
# Processing Record 25 of Set 8 | isafjordur
# Processing Record 26 of Set 8 | mossel bay
# Processing Record 27 of Set 8 | faya-largeau
# Processing Record 28 of Set 8 | daru
# Processing Record 29 of Set 8 | chui
# Processing Record 30 of Set 8 | storozhevaya
# Processing Record 31 of Set 8 | griffith
# Processing Record 32 of Set 8 | tura
# Processing Record 33 of Set 8 | matoury
# Processing Record 34 of Set 8 | sao vicente
# Processing Record 35 of Set 8 | baruun-urt
# Processing Record 36 of Set 8 | kyren
# Processing Record 37 of Set 8 | masoko
# Processing Record 38 of Set 8 | kralendijk
# Processing Record 39 of Set 8 | walvis bay
# Processing Record 40 of Set 8 | chibougamau
# Processing Record 41 of Set 8 | ryotsu-minato
# Processing Record 42 of Set 8 | khenchela
# Processing Record 43 of Set 8 | sandnessjoen
# Processing Record 44 of Set 8 | kavieng
# Processing Record 45 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 47 of Set 8 | qulsary
# Processing Record 48 of Set 8 | ballina
# Processing Record 49 of Set 8 | moundsville
# Processing Record 0 of Set 9 | bayganin
# Processing Record 1 of Set 9 | yuzhno-sukhokumsk
# Processing Record 2 of Set 9 | asau
# Processing Record 3 of Set 9 | trinidad
# Processing Record 4 of Set 9 | tela
# Processing Record 5 of Set 9 | plouzane
# Processing Record 6 of Set 9 | yeppoon
# Processing Record 7 of Set 9 | tamanrasset
# Processing Record 8 of Set 9 | durban
# Processing Record 9 of Set 9 | naze
# Processing Record 10 of Set 9 | soavinandriana
# Processing Record 11 of Set 9 | sinabang
# Processing Record 12 of Set 9 | floro
# Processing Record 13 of Set 9 | sompeta
# Processing Record 14 of Set 9 | palmer
# Processing Record 15 of Set 9 | mandera
# Processing Record 16 of Set 9 | cooper's town
# Processing Record 17 of Set 9 | bamboo flat
# Processing Record 18 of Set 9 | kiunga
# Processing Record 19 of Set 9 | lijiang
# Processing Record 20 of Set 9 | hengchun
# Processing Record 21 of Set 9 | al muwayh
# Processing Record 22 of Set 9 | santo antonio
# Processing Record 23 of Set 9 | biloxi
# Processing Record 24 of Set 9 | ninghai
# Processing Record 25 of Set 9 | alofi
# Processing Record 26 of Set 9 | escarcega
# Processing Record 27 of Set 9 | bhamo
# Processing Record 28 of Set 9 | shinkafi
# Processing Record 29 of Set 9 | paracatu
# Processing Record 30 of Set 9 | ashchysay
# Processing Record 31 of Set 9 | keetmanshoop
# Processing Record 32 of Set 9 | vallenar
# Processing Record 33 of Set 9 | awjilah
# Processing Record 34 of Set 9 | arteche
# Processing Record 35 of Set 9 | kenscoff
# Processing Record 36 of Set 9 | maintirano
# Processing Record 37 of Set 9 | beau vallon
# Processing Record 38 of Set 9 | robore
# Processing Record 39 of Set 9 | bhimunipatnam
# Processing Record 40 of Set 9 | sivas
# Processing Record 41 of Set 9 | cabo san lucas
# Processing Record 42 of Set 9 | bismarck
# Processing Record 43 of Set 9 | ko pha ngan
# Processing Record 44 of Set 9 | itoman
# Processing Record 45 of Set 9 | belaya glina
# Processing Record 46 of Set 9 | flin flon
# Processing Record 47 of Set 9 | luderitz
# Processing Record 48 of Set 9 | novomyrhorod
# Processing Record 49 of Set 9 | harstad
# Processing Record 0 of Set 10 | uige
# Processing Record 1 of Set 10 | nar'yan-mar
# Processing Record 2 of Set 10 | botelhos
# Processing Record 3 of Set 10 | vryburg
# Processing Record 4 of Set 10 | zag
# Processing Record 5 of Set 10 | new norfolk
# Processing Record 6 of Set 10 | kodinsk
# Processing Record 7 of Set 10 | damasak
# Processing Record 8 of Set 10 | mpongwe
# Processing Record 9 of Set 10 | targuist
# Processing Record 10 of Set 10 | maumere
# Processing Record 11 of Set 10 | taikang
# Processing Record 12 of Set 10 | sur
# Processing Record 13 of Set 10 | holland
# Processing Record 14 of Set 10 | ghanzi
# Processing Record 15 of Set 10 | dryden
# Processing Record 16 of Set 10 | paola
# Processing Record 17 of Set 10 | aguas vermelhas
# Processing Record 18 of Set 10 | muli
# Processing Record 19 of Set 10 | tabanan
# Processing Record 20 of Set 10 | veymandoo
# City not found. Skipping...
# Processing Record 21 of Set 10 | la reforma
# Processing Record 22 of Set 10 | port macquarie
# Processing Record 23 of Set 10 | saksaul'skiy
# City not found. Skipping...
# Processing Record 24 of Set 10 | fale old settlement
# Processing Record 25 of Set 10 | geraldton
# Processing Record 26 of Set 10 | gadzhiyevo
# Processing Record 27 of Set 10 | markovo
# Processing Record 28 of Set 10 | usogorsk
# Processing Record 29 of Set 10 | harar
# Processing Record 30 of Set 10 | zehdenick
# Processing Record 31 of Set 10 | jatai
# Processing Record 32 of Set 10 | ubinskoye
# Processing Record 33 of Set 10 | collie
# Processing Record 34 of Set 10 | port blair
# Processing Record 35 of Set 10 | tokmok
# Processing Record 36 of Set 10 | borogontsy
# Processing Record 37 of Set 10 | chatillon-sur-seine
# Processing Record 38 of Set 10 | mhamid
# Processing Record 39 of Set 10 | kirishi
# Processing Record 40 of Set 10 | lalganj
# Processing Record 41 of Set 10 | egilsstadir
# Processing Record 42 of Set 10 | strezhevoy
# Processing Record 43 of Set 10 | arroio grande
# Processing Record 44 of Set 10 | fagersta
# Processing Record 45 of Set 10 | akureyri
# Processing Record 46 of Set 10 | gillette
# Processing Record 47 of Set 10 | pinotepa nacional
# Processing Record 48 of Set 10 | grand baie
# Processing Record 49 of Set 10 | verkhovyna
# Processing Record 0 of Set 11 | kristiansund
# Processing Record 1 of Set 11 | pacocha
# Processing Record 2 of Set 11 | juye
# Processing Record 3 of Set 11 | lackland air force base
# Processing Record 4 of Set 11 | manaure
# Processing Record 5 of Set 11 | alta
# Processing Record 6 of Set 11 | promyshlennaya
# Processing Record 7 of Set 11 | alo
# Processing Record 8 of Set 11 | hola
# Processing Record 9 of Set 11 | holualoa
# Processing Record 10 of Set 11 | shangri-la
# City not found. Skipping...
# Processing Record 11 of Set 11 | ocean pointe
# City not found. Skipping...
# Processing Record 12 of Set 11 | tarawa
# Processing Record 13 of Set 11 | mawu
# Processing Record 14 of Set 11 | atar
# Processing Record 15 of Set 11 | wau
# Processing Record 16 of Set 11 | lewistown
# Processing Record 17 of Set 11 | belle fourche
# Processing Record 18 of Set 11 | novospasskoye
# Processing Record 19 of Set 11 | saint-joseph
# Processing Record 20 of Set 11 | sungai penuh
# Processing Record 21 of Set 11 | ash shafa
# Processing Record 22 of Set 11 | nova vicosa
# Processing Record 23 of Set 11 | sekong
# Processing Record 24 of Set 11 | darfo boario terme
# Processing Record 25 of Set 11 | san ignacio
# Processing Record 26 of Set 11 | salinopolis
# Processing Record 27 of Set 11 | al kharijah
# Processing Record 28 of Set 11 | urengoy
# Processing Record 29 of Set 11 | rosetta
# Processing Record 30 of Set 11 | elista
# Processing Record 31 of Set 11 | sierra grande
# Processing Record 32 of Set 11 | nevel'sk
# Processing Record 33 of Set 11 | brigham city
# Processing Record 34 of Set 11 | papao
# Processing Record 35 of Set 11 | shimoda
# Processing Record 36 of Set 11 | sheridan
# Processing Record 37 of Set 11 | gilgit
# Processing Record 38 of Set 11 | caninde de sao francisco
# Processing Record 39 of Set 11 | santana
# Processing Record 40 of Set 11 | vorkuta
# Processing Record 41 of Set 11 | kosh-agach
# Processing Record 42 of Set 11 | thakhek
# Processing Record 43 of Set 11 | cable beach
# City not found. Skipping...
# Processing Record 44 of Set 11 | nizhnyaya poyma
# Processing Record 45 of Set 11 | rodna
# Processing Record 46 of Set 11 | bandar-e anzali
# Processing Record 47 of Set 11 | tralee
# Processing Record 48 of Set 11 | khandyga
# Processing Record 49 of Set 11 | alvaraes
# Processing Record 0 of Set 12 | norilsk
# Processing Record 1 of Set 12 | nikolayevsk-on-amure
# Processing Record 2 of Set 12 | abra pampa
# Processing Record 3 of Set 12 | sishilichengzi
# City not found. Skipping...
# Processing Record 4 of Set 12 | howard springs
# Processing Record 5 of Set 12 | roma
# Processing Record 6 of Set 12 | kiruna
# Processing Record 7 of Set 12 | cocal
# Processing Record 8 of Set 12 | laojunmiao
# Processing Record 9 of Set 12 | kismayo
# Processing Record 10 of Set 12 | hauterive
# Processing Record 11 of Set 12 | novo aripuana
# Processing Record 12 of Set 12 | itai
# Processing Record 13 of Set 12 | lamu
# Processing Record 14 of Set 12 | dunafoldvar
# Processing Record 15 of Set 12 | islamkot
# Processing Record 16 of Set 12 | aoulef
# Processing Record 17 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 12 | gokwe
# Processing Record 19 of Set 12 | teplyk
# Processing Record 20 of Set 12 | usinsk
# Processing Record 21 of Set 12 | tarancon
# Processing Record 22 of Set 12 | vilyuchinsk
# Processing Record 23 of Set 12 | jwaneng
# Processing Record 24 of Set 12 | genhe
# Processing Record 25 of Set 12 | callao
# Processing Record 26 of Set 12 | ust'-kulom
# Processing Record 27 of Set 12 | aykhal
# Processing Record 28 of Set 12 | uzice
# Processing Record 29 of Set 12 | banora point
# Processing Record 30 of Set 12 | talavera
# Processing Record 31 of Set 12 | ejea de los caballeros
# Processing Record 32 of Set 12 | dambulla
# Processing Record 33 of Set 12 | tikamgarh
# Processing Record 34 of Set 12 | barrouallie
# Processing Record 35 of Set 12 | saint joseph
# Processing Record 36 of Set 12 | kapsowar
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Pressure      564
# Country       564
# Date          564
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Weno   7.4515  151.8468     82.35        83         100
# 1         George Town   5.4112  100.3354     76.95        87          40
# 2  Brisas de Zicatela  15.8369  -97.0419     81.12        83           0
# 3             Klyuchi  52.2667   79.1667     15.96        81           3
# 4            Pugachev  52.0133   48.8025     28.54        68          99
#
#    Wind Speed  Pressure Country        Date
# 0        4.61      1007      FM  1732758669
# 1        9.22      1011      MY  1732758395
# 2        0.00      1011      MX  1732758672
# 3        7.61      1029      RU  1732758674
# 4        5.48      1024      RU  1732758675

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      Weno   7.4515  151.8468     82.35        83
# 1               George Town   5.4112  100.3354     76.95        87
# 2        Brisas de Zicatela  15.8369  -97.0419     81.12        83
# 3                   Klyuchi  52.2667   79.1667     15.96        81
# 4                  Pugachev  52.0133   48.8025     28.54        68
#
#          Cloudiness  Wind Speed  Pressure Country        Date
# City_ID
# 0               100        4.61      1007      FM  1732758669
# 1                40        9.22      1011      MY  1732758395
# 2                 0        0.00      1011      MX  1732758672
# 3                 3        7.61      1029      RU  1732758674
# 4                99        5.48      1024      RU  1732758675

# %%
# Date Cleaning w/dates
city_data_df["Date"] = pd.to_datetime(city_data_df.Date * 1e9)
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      Weno   7.4515  151.8468     82.35        83
# 1               George Town   5.4112  100.3354     76.95        87
# 2        Brisas de Zicatela  15.8369  -97.0419     81.12        83
# 3                   Klyuchi  52.2667   79.1667     15.96        81
# 4                  Pugachev  52.0133   48.8025     28.54        68
#
#          Cloudiness  Wind Speed  Pressure Country                Date
# City_ID
# 0               100        4.61      1007      FM 2024-11-28 01:51:09
# 1                40        9.22      1011      MY 2024-11-28 01:46:35
# 2                 0        0.00      1011      MX 2024-11-28 01:51:12
# 3                 3        7.61      1029      RU 2024-11-28 01:51:14
# 4                99        5.48      1024      RU 2024-11-28 01:51:15

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(city_data_df.Lat, city_data_df["Max Temp"], color="green", edgecolor="black", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Latitude", fontfamily="Times New Roman", fontsize=12)
plt.ylabel("Temperature", fontfamily="Times New Roman", fontsize=12)
plt.title("Latitude vs Temperature", fontweight="bold", fontsize=16, fontfamily="Times New Roman")

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(city_data_df.Lat, city_data_df["Humidity"], color="blue", edgecolor="black", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Latitude", fontfamily="Times New Roman", fontsize=12)
plt.ylabel("Humidity", fontfamily="Times New Roman", fontsize=12)
plt.title("Latitude vs Humidity", fontweight="bold", fontsize=16, fontfamily="Times New Roman")

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. Cloudiness

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(city_data_df.Lat, city_data_df["Cloudiness"], color="red", edgecolor="black", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Latitude", fontfamily="Times New Roman", fontsize=12)
plt.ylabel("Cloudiness", fontfamily="Times New Roman", fontsize=12)
plt.title("Latitude vs Cloudiness", fontweight="bold", fontsize=16, fontfamily="Times New Roman")

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. Wind Speed Plot

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(city_data_df.Lat, city_data_df["Wind Speed"], color="orange", edgecolor="black", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Latitude", fontfamily="Times New Roman", fontsize=12)
plt.ylabel("Wind Speed", fontfamily="Times New Roman", fontsize=12)
plt.title("Latitude vs Wind Speed", fontweight="bold", fontsize=16, fontfamily="Times New Roman")

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def do_regression_plot(x_values, y_values, x_label, y_label, annotation):  
    # do regression
    (slope, intercept, rvalue, pvalue, stderr) = sc.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept # these are the points/predictions
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    print(rvalue)
    print(line_eq)

    # Change Canvas Size
    plt.figure(figsize=(12, 6))
    
    # Create a basic plot
    plt.scatter(x_values, y_values, color="blue", edgecolor="black", s=200)
    plt.plot(x_values, regress_values, color="black", linewidth=6) # the regression line
    
    # Customizations
    
    # Change colors
    # Add in reference lines
    # Add Labels/Title
    plt.xlabel(x_label, fontfamily="Times New Roman", fontsize=12)
    plt.ylabel(y_label, fontfamily="Times New Roman", fontsize=12)
    plt.title(f"{x_label} vs {y_label}", fontweight="bold", fontsize=16, fontfamily="Times New Roman")
    
    # Add in a background grid
    plt.grid(linestyle="--", color="lightgrey", alpha=0.75)
    
    # Annotate
    plt.annotate(line_eq, annotation, fontsize=15, color="black")
    
    # Show/Save the Graph
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df.Lat >= 0].reset_index(drop=True)

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Weno   7.4515  151.8468     82.35        83         100
# 1         George Town   5.4112  100.3354     76.95        87          40
# 2  Brisas de Zicatela  15.8369  -97.0419     81.12        83           0
# 3             Klyuchi  52.2667   79.1667     15.96        81           3
# 4            Pugachev  52.0133   48.8025     28.54        68          99
#
#    Wind Speed  Pressure Country                Date
# 0        4.61      1007      FM 2024-11-28 01:51:09
# 1        9.22      1011      MY 2024-11-28 01:46:35
# 2        0.00      1011      MX 2024-11-28 01:51:12
# 3        7.61      1029      RU 2024-11-28 01:51:14
# 4        5.48      1024      RU 2024-11-28 01:51:15

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df.Lat < 0].reset_index(drop=True)

# Display sample data
southern_hemi_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hithadhoo  -0.6000   73.0833     82.60        82          98
# 1     Grytviken -54.2811  -36.5092     28.96        70          46
# 2  Invercargill -46.4000  168.3500     58.01        91          99
# 3      Waitangi -43.9535 -176.5597     55.74        88         100
# 4     Adamstown -25.0660 -130.1015     72.79        75         100
#
#    Wind Speed  Pressure Country                Date
# 0       18.77      1009      MV 2024-11-28 01:51:16
# 1        6.98       996      GS 2024-11-28 01:51:17
# 2       18.01      1005      NZ 2024-11-28 01:51:18
# 3       25.03      1018      NZ 2024-11-28 01:51:22
# 4       14.83      1021      PN 2024-11-28 01:46:26

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temperature"
annotation = (5, 20)

do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# -0.8722877454159926
# y = -1.15x + 89.07

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df.Lat
y_values = southern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temperature"
annotation = (-20, 40)

do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.5796218047860484
# y = 0.51x + 82.26

# %% [markdown]
# ###

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemi As latitude moves away from equator temperature goes down and vice versa for the south hemi as latitude moves closer to the equator temperature goes up.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df["Humidity"]
x_label = "Latitude"
y_label = "Humidity"
annotation = (55, 30)

do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.35054830296224665
# y = 0.37x + 59.53

# %%
# Southern Hemisphere
x_values = southern_hemi_df.Lat
y_values = southern_hemi_df["Humidity"]
x_label = "Latitude"
y_label = "Humidity"
annotation = (-20, 50)

do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.16296691847685127
# y = 0.21x + 79.76

# %% [markdown]
# **Discussion about the linear relationship:** For the northern hemisphere, as latitude is moving away from equator the humidity rises. For the southern hemisphere as latitude gets closer to the equator, not as much as northern but still slight increase in humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df["Cloudiness"]
x_label = "Latitude"
y_label = "Cloudiness"
annotation = (65, 0)

do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.21902816465298272
# y = 0.47x + 36.1

# %%
x_values = southern_hemi_df.Lat
y_values = southern_hemi_df["Cloudiness"]
x_label = "Latitude"
y_label = "Cloudiness"
annotation = (-55, 20)

do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.16737912855693862
# y = 0.48x + 70.64

# %% [markdown]
# **Discussion about the linear relationship:** For cloudiness, there shows a slight positive regression when moving away from equator on northern hemisphere, and also getting closer to equator in southern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed"
annotation = (10, 35)

do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# -0.008845637656965374
# y = -0.0x + 7.99

# %%
x_values = southern_hemi_df.Lat
y_values = southern_hemi_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed"
annotation = (-50, 22)

do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# -0.2243192674073015
# y = -0.1x + 6.21

# %% [markdown]
# **Discussion about the linear relationship:** Northern hemisphere shows no relationship, however southern hemisphere has a negative regression when latitude is moving closer to the equator.
